# %%
import numpy as np
# Read first B52K3P3G files
from pyedflib import highlevel
from pathlib import Path

BASE_DIR = Path('/data/home/webb/UNEEG_data')
patient = 'B52K3P3G'
edf_dir = Path(f'/data/home/webb/UNEEG_data/20240201_UNEEG_ForMayo/{patient}/edf_data')
edf1_path = edf_dir / 'B52K3P3G_2021-10-08_12-31-42.edf'
edf2_path = edf_dir / 'B52K3P3G_2021-10-08_18-32-22.edf'

signals1, signal_headers1, header1 = highlevel.read_edf(str(edf1_path))
signals2, signal_headers2, header2 = highlevel.read_edf(str(edf2_path))

# %%
# the end of signals1
cutout1 = signals1[:, -300:]
# the beginning of signals2
cutout2 = signals2[:, :300]

# %%
import matplotlib.pyplot as plt

plt.plot(cutout1[0, :])

# %%
cutout1[0, -1]
# Out:
# np.float64(-1374.21)

# %%
import numpy as np
arr = np.array([0, 1, 2, 3])
arr
# Out:
# array([0, 1, 2, 3])

# %%
print(arr[-2:])
# Out:
# [2 3]

# %%
print(arr[:2])
# Out:
# [0 1]

# %%
arr[2]
# Out:
# np.int64(2)
