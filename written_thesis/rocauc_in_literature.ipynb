# %%
import pandas as pd

# %%
# In Müller 2022

data = {
    "Patient": [
        "Pat A", "Pat B", "Pat C", "Pat D",
        "Pat E", "Dog 1", "Dog 2", "Dog 3", "Dog 4",
        "Pat 1", "Pat 2", "Pat 3"
    ],
    "Ensemble_AUC": [
        0.83, 0.23, 0.89, 0.63,
        0.97, 0.97, 0.89, 0.89, 0.93,
        0.63, 0.82, 0.83
    ],
    "CNN_AUC": [
        0.77, 0.22, 0.88, 0.33,
        0.88, 0.82, 0.80, 0.83, 0.90,
        0.24, 0.74, 0.75
    ]
}

df = pd.DataFrame(data)
df.set_index("Patient", inplace=True)

df
# Out:
#          Ensemble_AUC  CNN_AUC
# Patient
# Pat A            0.83     0.77
# Pat B            0.23     0.22
# Pat C            0.89     0.88
# Pat D            0.63     0.33
# Pat E            0.97     0.88
# Dog 1            0.97     0.82
# Dog 2            0.89     0.80
# Dog 3            0.89     0.83
# Dog 4            0.93     0.90
# Pat 1            0.63     0.24
# Pat 2            0.82     0.74
# Pat 3            0.83     0.75

# %%
df.mean()
# Out:
# Ensemble_AUC    0.7925
# CNN_AUC         0.6800
# dtype: float64

# %%
df.max()
# Out:
# Ensemble_AUC    0.97
# CNN_AUC         0.90
# dtype: float64

# %%
df.min()
# Out:
# Ensemble_AUC    0.23
# CNN_AUC         0.22
# dtype: float64
